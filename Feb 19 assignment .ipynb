# %% [markdown]
# Q1. What is Flask Framework? What are the advantages of Flask Framework?
# Flask is a web framework. Flask allows you to build a web application by providing tools, libraries, and technologies. This web application will be a web page, a wiki, or a big web-based calendar application or commercial website. Flask is classified into a micro-framework that means it has little to no dependencies on external libraries.
#
# ADVANTAGES:
#
#     Integrated support for unit testing
#
#     Built-in development server and fast debugger
#
#     Restful request dispatching
#
#     Unicode base
#
#     Support for cookies
#
#     Templating jinja2
#
#     WSGI 1.0 compliant
#
#     Plus flask gives US some premier control to develop our project.
#
#     HTTP request handling function
#
#     Flask has a modular design and lightweight so that it can easy to transit into web framework with some extension
#
#     Basic fundamental API is nicely shaped and coherent
#
#     Highly flexible
#
#     It is easy to deploy the flask in production

# %% [markdown]
# Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in
# Jupyter Notebook.
#
# ![Flask screenshot.png](attachment:35313eec-c7d5-42d9-b650-1646a1dd01e0.png)

# %% [markdown]
# Q3. What is App routing in Flask? Why do we use app routes?
#
# App Routing means mapping the URLs to a specific function that will handle the logic for that URL. Modern web frameworks use more meaningful URLs to help users remember the URLs and make navigation simpler. The routing technique helps a user remember application URLs and is useful to access the desired page directly without having to navigate from the home page.

# %% [markdown]
# Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”
# route to show the following details:
# Company Name: ABC Corporation
# Location: India
# Contact Detail: 999-999-9999

# %% [markdown]
# ![Screenshot 2023-05-08 191156.png](attachment:d855e4d5-12cd-4e5b-84f8-a9100fd6b06e.png)

# %% [markdown]
# ![Screenshot 2023-05-08 191955.png](attachment:ecee72cc-63a4-4e21-b779-6df6d0960c87.png)

# %% [markdown]
# Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the
# url_for() function.
# The url_for() function is very useful for dynamically building a URL for a specific function. The function accepts the name of a function as first argument, and one or more keyword arguments, each corresponding to the variable part of URL.

# %%
from flask import Flask, redirect, url_for

app = Flask(__name__)
@app.route("/home")
def home():
    return "<h1>Welcome to ABC Corporation</h1>"
@app.route("/contact")
def contact():
    a= "Company Name: ABC Corporation<br>Location: India<br>Contact Detail: 999-999-9999"
    return a
@app.route("/display/<x>")
def func(x):
    if x=="home":
        return redirect(url_for("home"))
    if x=="contact":
        return redirect(url_for("contact"))
if __name__=="__main__":
    app.run(host="0.0.0.0")

# %% [markdown]
# output:
#
# ![Screenshot 2023-05-08 220927.png](attachment:77643cde-e60b-4320-90b0-46b630ab4c50.png)
#
# ![Screenshot 2023-05-08 221016.png](attachment:a972cc7d-c78f-4d3c-85f6-4f566a221202.png)
